# %% [markdown]
# # Homework 1
# ## ASTR 598
# ### Iryna Butsky & Margaret Lazzarini

# %%
Pkg.add("PyPlot")
using PyPlot
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %% [markdown]
# Kepler's Equation:
# M = E-esinE

# %%
function Kepler(M, e)
    E_old = M
    epsilon = 1.0
    while epsilon > 1.0E-12
        g = E_old - e*sin(E_old) - M
        g_prime = 1.0 - e*cos(E_old)
        E_new = E_old - (g/g_prime)
        epsilon = abs(E_old - E_new)/E_old
        E_old = E_new
    end
    return E_old
end
# Out:
# Kepler (generic function with 1 method)

# %%
e = [0.0 0.25 0.5 0.75]
M = linspace(0,2.0*pi, 100)
E = Array{Float64}(100)
color = ["red", "green", "blue", "black"]
label = ["0.0", "0.25", "0.5", "0.75"]
for j = 1:4
    for i = 1:100
        E[i] = Kepler(M[i],e[j])
    end
    scatter(M, E, color=color[j], label=label[j])
end
legend(loc=4)
xlabel("M")
ylabel("E")
title("Solutions to Kepler's Equation")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x314a75390>)
# PyObject <matplotlib.text.Text object at 0x314babd10>
