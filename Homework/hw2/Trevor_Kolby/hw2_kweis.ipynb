# %%
# Add relative path to ExoJulia
push!(LOAD_PATH, "../../../ExoJulia/")

# import
using ExoJulia
using LsqFit
using PyPlot

# %%
# include RV scripts
# if you're using the notebook, comment out line 11 of rv.jl
include("rv.jl")
# Out:
# plot_RV (generic function with 1 method)

# %%
data = readdlm("mystery_planet.txt",Float64) ;

# %%
times = data[:,1]
RVs = data[:,2]
RV_errs = data[:,3] ;

# %%
@time result = fit_RV(times,RVs,RV_errs) ;
# Out:
#   0.233196 seconds (396.92 k allocations: 98.975 MB, 7.15% gc time)

# %%
param_names = ["e","t_p","P","K","pomega","gamma"]
for (param,res) in zip(param_names,result)
    println("$param = $res")
end
# Out:
# e = 0.4001661232072664
# t_p = 13891.356528538308
# P = 116.6856950634916
# K = 316.10900920045964
# pomega = -0.7766860911575227
# gamma = -51.91666956578172

# %%
plot_RV(times, RVs, result[3]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32470df90>)
