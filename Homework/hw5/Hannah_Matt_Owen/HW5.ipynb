# %%
include("planet_moon_star.jl")

yplanet = 10.
y1moon = 0
y2moon = 0
eps1 = 1e-5
eps2 = 0.5
map = planet_moon_star(yplanet,y1moon,y2moon,eps1,eps2)
print(size(map))

#print(x)
radii = collect(0.25:0.7:4)
max = zeros(length(radii))

for (k,radius) in enumerate(radii)
    x = zeros(Float64, (1000,1000))
    for (i=1:1000)
        for(j=1:1000)
            if ((i-500)^2+(j-500)^2 < (radius*100)^2)
                x[i,j] = 1
            end
        end
    end
    println(k)
    max[k] = maximum(conv2(map,x))/(pi*radius^2)
end
# Out:
# Mass ratio: 1.0e-5
# 1000/10000
# 2000/10000
# 3000/10000
# 4000/10000
# 5000/10000
# 6000/10000
# 7000/10000
# 8000/10000
# 9000/10000
# 10000/10000
# Range of grid, y1: 9.984188611699158 9.984190192837989 10.015811388300842 10.015809807162011
# Range of grid, y2: -0.047434164902525694 -0.0082203407776077 0.047434164902525694 0.008220340777607707
# (1000,1000)1
# 2
# 3
# 4
# 5
# 6
# LoadError: syntax: "%" is not a unary operator
# while loading In[2], in expression starting on line 29

# %%
using PyPlot
figure(figsize=(12,8))
plot(radii,max)
#show(radii,max,extent=[-4,4,-1,1])
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f146390>)

# %%
d_l = 5.
d_s = 8.
r_E = 2.2*sqrt(4*(d_l/d_s)*(1-d_l/d_s))
println("Einstein radius: ",r_E," AU")
println("Einstein angle: ",r_E/d_l," mas")
# Out:
# Einstein radius: 2.1301408404140796 AU
# Einstein angle: 0.4260281680828159 mas

# %%
r_s = (1.2)^2
println("Angular size of source needed for 20% greater magnification: ", r_s, " R_source,0")
# Out:
# Angular size of source needed for 20% greater magnification: 1.44 R_source,0

# %% [markdown]
# A larger source like a giant star would be an ineffective target for microlensing surveys because larger sources will be magnified less. WFIRST-AFTA's wide field of view would be good for observing such low-probability events. Since it is an infrared survey, it will also allow more observations of smaller, low-mass source stars as well as penetration of high-density regions like the galactic bulge.
