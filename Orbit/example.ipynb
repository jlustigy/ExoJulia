# %% [markdown]
# # Testing Kepler's Equation
# Authors: David Fleming & Jake Lustig-Yaeger

# %% [markdown]
# ### 1. `push` directory to `LOAD_PATH` julia variable
# In general, mature packages should be in `~/.julia`

# %%
push!(LOAD_PATH, "/Users/dflemin3/Desktop/Career/Grad_Classes/Exoplanets/ExoJulia/Orbit")
# Out:
# 3-element Array{ByteString,1}:
#  "/Applications/Julia-0.4.5.app/Contents/Resources/julia/local/share/julia/site/v0.4"
#  "/Applications/Julia-0.4.5.app/Contents/Resources/julia/share/julia/site/v0.4"
#  "/Users/dflemin3/Desktop/Career/Grad_Classes/Exoplanets/ExoJulia/Orbit"

# %% [markdown]
# ### 2. `import` modules
# There are the `*.jl` files

# %%
import KeplerSolver, KeplerSolver_test

# %% [markdown]
# ### 3. Run first test function

# %%
KeplerSolver_test.testKeplerEquation1()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31bdf5ed0>)

# %% [markdown]
# ### 4. Run second test function (Residuals)

# %%
KeplerSolver_test.testKeplerEquation2()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31be06450>)
