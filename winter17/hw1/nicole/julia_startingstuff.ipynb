# %%
# NOTES:
# Everything needs an end statement in Julia
# Use Julia in ipython notebooks


Pkg.add("PyPlot")
#Pkg.update("PyPlot")
using PyPlot

x = linspace(0,2*pi,1000)
y = sin(3*x + 4*cos(2*x))

plot(x, y, color="red", linewidth=2.0, linestyle="--")

#plot(x)

# Make random vector
#x=randn(1000)
#plot(x)
#y = linspace(0,10,1000)
#plot(y,x)

#clf()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319615710>)
# INFO: Nothing to be done
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31ca06128>

# %%
plot(x,y)

# %%
function sum_squares(x)
    sumsq = total(x.*x2)  # take dot product of x dot x, but for dot product of x vectors need period before exponent
end

print ln(sum_squares(x))

# %%
# Stuff!
